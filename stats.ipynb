# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stat
from statistics import mode

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_iris=pd.read_csv("Iris.csv")

# %%
df_titanic= pd.read_csv("Titanic.csv")

# %%
df_iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
df_titanic["Age"].median()
# Out:
# 28.0

# %%
df_titanic["Age"].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df_titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_iris["SepalLengthCm"].mean()
# Out:
# 5.843333333333334

# %%
df_iris["SepalLengthCm"].median()
# Out:
# 5.8

# %%
df_iris["SepalLengthCm"].mode()
# Out:
# 0    5.0
# Name: SepalLengthCm, dtype: float64

# %%
from scipy import stats as st

# %%
st.mode(df_iris["SepalLengthCm"])
# Out:
# ModeResult(mode=array([5.]), count=array([10]))

# %%
x=[23,24,32,45,12,43,67,45,32,56,32]

# %%
mean=0
s=0
for i in x: 
    s=s+i

# %%
mean=s/len(x)
print(mean)
# Out:
# 37.36363636363637

# %%
np.mean(x)
# Out:
# 37.36363636363637

# %%
m=sorted(x)

# %%
med=0
if len(x)%2==0:
    mid = len(m)/2
    med= (m[mid-1] + m[mid])/2
    print(med)
else:
    mid = int(len(m)/2)
    med= m[mid]
    print(med)
# Out:
# 32

# %%
np.median(x)
# Out:
# 32.0

# %%
# Despersion of the data

# %%
x_copy=x.copy()

# %%
x_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
x_copy.append(150)

# %%
x_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32, 150]

# %%
x_copy1=x.copy()

# %%
x_copy1.append(75)

# %%
np.mean(x_copy)
# Out:
# 46.75

# %%
np.mean(x_copy1)
# Out:
# 40.5

# %%
np.median(x_copy)
# Out:
# 37.5

# %%
np.median(x_copy1)
# Out:
# 37.5

# %%
np.median(x)
# Out:
# 32.0

# %%
x
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
np.percentile(x,[25])
# Out:
# array([28.])

# %%
x.sort()

# %%
x
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
np.percentile(x,[25,50,75,100])
# Out:
# array([28., 32., 45., 67.])

# %%
'''
IQR=Q3-Q1

lower_fence= Q1-1.5*IQR
upper_fence= Q3+1.5*IQR

'''
sns.boxplot(x_copy)
# Out:
# <Axes: >

# %%
# Varience and Standard deviation

# %%
np.var(x)
# Out:
# 226.23140495867767

# %%
np.std(x)
# Out:
# 15.040990823701664

# %%
# Sample and population

# Question : Find out at leat 5 techniques of smpling and implement it with the help of python

# %%
df_iris.sample(25)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 61    62            5.9           3.0            4.2           1.5
# 110  111            6.5           3.2            5.1           2.0
# 88    89            5.6           3.0            4.1           1.3
# 0      1            5.1           3.5            1.4           0.2
# 131  132            7.9           3.8            6.4           2.0
# 2      3            4.7           3.2            1.3           0.2
# 51    52            6.4           3.2            4.5           1.5
# 18    19            5.7           3.8            1.7           0.3
# 106  107            4.9           2.5            4.5           1.7
# 72    73            6.3           2.5            4.9           1.5
# 101  102            5.8           2.7            5.1           1.9
# 125  126            7.2           3.2            6.0           1.8
# 94    95            5.6           2.7            4.2           1.3
# ...

# %%
np.random.choice(x, size=3)
# Out:
# array([45, 67, 23])

# %%
# Varience function with the help of python

def var(x):
    v=0
    for i in x:
        c= (i-np.mean(x))**2/(len(x)-1)
        v=v+c
    return v

# %%
var(df_iris["SepalLengthCm"])
# Out:
# 0.6856935123042511

# %%
np.var(df_iris["SepalLengthCm"])
# Out:
# 0.6811222222222223

# %%
stat.variance(df_iris["SepalLengthCm"])
# Out:
# 0.6856935123042506

# %%
# Finding Standard deviation

# %%
import math

# %%
standard_deviation=math.sqrt(stat.variance(df_iris["SepalLengthCm"]))

# %%
standard_deviation
# Out:
# 0.8280661279778629

# %%
np.std(df_iris["SepalLengthCm"])
# Out:
# 0.8253012917851409

# %%
iris=df_iris.drop(labels=["Species","Id"], axis=1)

# %%
iris.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.pairplot(iris)

# %%
sns.scatterplot(iris)
# Out:
# <Axes: >

# %%
iris.cov()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       0.685694     -0.039268       1.273682      0.516904
# SepalWidthCm       -0.039268      0.188004      -0.321713     -0.117981
# PetalLengthCm       1.273682     -0.321713       3.113179      1.296387
# PetalWidthCm        0.516904     -0.117981       1.296387      0.582414

# %%
#PDF : Probability Distribution Function

# %%
x=0
for i in iris.columns:
    sns.histplot(iris[i],kde=True)
    print('\n')
    plt.show()

# %%
m=np.random.normal(3,1,1000)

# %%
sns.histplot(m,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
n=np.random.lognormal(3,1,1000)

# %%
sns.histplot(n,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(n),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
x=0
for i in iris.columns:
    sns.histplot(np.log(iris[i]),kde=True)
    print('\n')
    plt.show()
